# %%
import tensorflow as tf
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential

# %% [markdown]
# # Get the data

# %%
train_df = pd.read_csv('train.csv')
val_df = pd.read_csv('val.csv')
test_df = pd.read_csv('test.csv')

# %% [markdown]
# ### Image preprocessing

# %%
BATCH_SIZE = 32
IMG_HEIGHT = 180
IMG_WIDTH = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  "training_set/training_set/",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE,
  )
# Out:
# Found 8005 files belonging to 2 classes.
# Using 6404 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  "training_set/training_set/",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE,
  )
# Out:
# Found 8005 files belonging to 2 classes.
# Using 1601 files for validation.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  "test_set/test_set/",
  #validation_split=0.2,
  #subset="test",
  #seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE,
  )
# Out:
# Found 2023 files belonging to 2 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cats', 'dogs']

# %% [markdown]
# For the training process we will use a total of 8005 images:
#
#
# *   6404 for training
# *   1601 for validation

# %% [markdown]
# ### Data standardisation

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# normalization_layer = layers.Rescaling(1./255)

# %%
# if ESTANDARIZAR_DATOS:
#   normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
#   image_batch, labels_batch = next(iter(normalized_ds))
#   first_image = image_batch[0]
#   # Notice the pixel values are now in `[0,1]`.
#   print(np.min(first_image), np.max(first_image))

# %% [markdown]
# # Model

# %%
num_classes = len(class_names)

# %%
custom_model = Sequential()

custom_model.add(Conv2D(filters = 64, kernel_size = (3,3), activation = "relu", input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)))
custom_model.add(Conv2D(filters = 64, kernel_size = (3,3), activation = "relu"))
custom_model.add(MaxPool2D(pool_size=(2,2)))

custom_model.add(Dropout(0.25))

custom_model.add(Conv2D(filters = 32, kernel_size = (3,3), activation = "relu"))
custom_model.add(Conv2D(filters = 32, kernel_size = (3,3), activation = "relu"))
custom_model.add(MaxPool2D(pool_size = (2,2)))

custom_model.add(Dropout(0.25))

custom_model.add(Conv2D(filters = 16, kernel_size = (3,3), activation = "relu"))
custom_model.add(Conv2D(filters = 16, kernel_size = (3,3), activation = "relu"))
custom_model.add(MaxPool2D(pool_size = (2,2)))

custom_model.add(Flatten())
custom_model.add(Dense(units = 12, activation = "relu"))
custom_model.add(Dense(units = 1, activation = "sigmoid"))

# %%
# Make sure you have frozen the correct layers
for i, layer in enumerate(custom_model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 conv2d True
# 1 conv2d_1 True
# 2 max_pooling2d True
# 3 dropout True
# 4 conv2d_2 True
# 5 conv2d_3 True
# 6 max_pooling2d_1 True
# 7 dropout_1 True
# 8 conv2d_4 True
# 9 conv2d_5 True
# 10 max_pooling2d_2 True
# 11 flatten True
# 12 dense True
# 13 dense_1 True

# %%
custom_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 178, 178, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 88, 88, 64)       0
#  )
#
#  dropout (Dropout)           (None, 88, 88, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 86, 86, 32)        18464
#
#  conv2d_3 (Conv2D)           (None, 84, 84, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 42, 42, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 42, 42, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 40, 40, 16)        4624
#
#  conv2d_5 (Conv2D)           (None, 38, 38, 16)        2320
#
#  max_pooling2d_2 (MaxPooling  (None, 19, 19, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 5776)              0
#
#  dense (Dense)               (None, 12)                69324
#
#  dense_1 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 142,713
# Trainable params: 142,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
custom_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_history = custom_model.fit(train_ds, validation_data = val_ds, epochs = 25)
# Out:
# Epoch 1/25
# 201/201 [==============================] - 48s 119ms/step - loss: 0.7798 - accuracy: 0.4889 - val_loss: 0.6932 - val_accuracy: 0.4884
# Epoch 2/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6932 - val_accuracy: 0.4878
# Epoch 3/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6932 - val_accuracy: 0.4878
# Epoch 4/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 5/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6932 - val_accuracy: 0.4878
# Epoch 6/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 7/25
# 201/201 [==============================] - 21s 107ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6932 - val_accuracy: 0.4878
# Epoch 8/25
# 201/201 [==============================] - 21s 105ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 9/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6932 - val_accuracy: 0.4878
# Epoch 10/25
# 201/201 [==============================] - 21s 105ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 11/25
# 201/201 [==============================] - 21s 107ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 12/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 13/25
# 201/201 [==============================] - 21s 105ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 14/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 15/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 16/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.4991 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 17/25
# 201/201 [==============================] - 21s 106ms/step - loss: 0.6932 - accuracy: 0.5009 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 18/25
# 201/201 [==============================] - 21s 105ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6933 - val_accuracy: 0.4878
# Epoch 19/25
# 189/201 [===========================>..] - ETA: 1s - loss: 0.6932 - accuracy: 0.5032
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-4d3286da40ef> in <module>()
#       1 #history = custom_model.fit(train_ds, epochs=10, validation_data=(val_ds))
# ----> 2 model_history = custom_model.fit(train_ds, validation_data = val_ds, epochs = 25)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs_range = range(25)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Model evaluation

# %%
# Generate generalization metrics
score = custom_model.evaluate(test_ds, verbose=1)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
